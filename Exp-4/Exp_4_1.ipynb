# %% [markdown]
# Objective:- WAP to evaluate the performance of implemented three-layer neural network with variations in activation functions, size of hidden layer, learning rate, batch size and number of epochs.

# %% [markdown]
# Description of model:-
# This is a fully connected neural network (MLP - Multi-Layer Perceptron) implemented using TensorFlow 1.x to classify images from the MNIST dataset. The model has:
# Input layer with 784 neurons (flattened 28x28 images).
# One hidden layer with tunable activation functions (ReLU, Sigmoid, Tanh) and tunable sizes (256, 128, 64 neurons).
# Output layer with 10 neurons (for digit classification).
# Adam Optimizer for training with cross-entropy loss function.

# %% [markdown]
# Description of code:-
# Data Preprocessing:
# Loads MNIST dataset using tensorflow_datasets (tfds).
# Normalizes pixel values (0-255 → 0-1) and flattens images.
# One-hot encodes labels for classification.
#
# Hyperparameter Tuning:
# Experiments with different activation functions (relu, sigmoid, tanh).
# Tests different hidden layer sizes (256, 128, 64).
#
# Model Definition:
# Placeholder variables (X for input, Y for labels).
# Weight and bias initialization for hidden and output layers.
# Defines the neural network architecture using tf.matmul() and activation functions.
#
# Training Process:
# Uses batch processing to train the model.
# Performs gradient updates using Adam Optimizer.
# Tracks loss and accuracy for each epoch.
#
# Evaluation & Visualization:
# Computes final test accuracy after training.
# Plots loss and accuracy curves for performance analysis.
# Generates confusion matrix to check classification errors.

# %% [markdown]
# Scope of improvement:-
# Upgrade to TensorFlow 2.x (tf.keras) for better performance and ease of use.
# Adding multiple layers can improve accuracy.
# Batch size = 10 is too small (it may cause slow training & noisy updates) instead we can try batch sizes like 32 or 64 for better convergence.

# %%
import tensorflow.compat.v1 as tf
import numpy as np
import tensorflow_datasets as tfds
import matplotlib.pyplot as plt
import time
from sklearn.metrics import confusion_matrix
import seaborn as sns

# Disable TensorFlow 2 behavior
tf.disable_v2_behavior()

# Load MNIST dataset
mnist = tfds.load('mnist', split=['train', 'test'], as_supervised=True)
train_data, test_data = mnist

# Network Parameters
input_size = 784  # 28x28 images
output_size = 10
learning_rate = 0.01
epochs = 50
batch_size = 10

# Hyperparameters to tune
activation_functions = {'relu': tf.nn.relu, 'sigmoid': tf.nn.sigmoid, 'tanh': tf.nn.tanh}
hidden_layer_sizes = [256, 128, 64]

# Function to preprocess images
def preprocess(images, labels):
    images = tf.cast(images, tf.float32) / 255.0  # Normalize
    images = tf.reshape(images, [784])  # Flatten
    labels = tf.one_hot(labels, depth=10)  # One-hot encode labels
    return images, labels

# Apply preprocessing and batch the data
train_data = train_data.map(preprocess).batch(batch_size)
test_data = test_data.map(preprocess).batch(batch_size)

# Placeholder for results
results = []

# Iterate over hyperparameters
for activation_name, activation_func in activation_functions.items():
    for hidden_layer_size in hidden_layer_sizes:
        print(f"Training with Activation: {activation_name}, Hidden Layer Size: {hidden_layer_size}")

        # Define placeholders
        X = tf.placeholder(tf.float32, [None, input_size])
        Y = tf.placeholder(tf.float32, [None, output_size])

        # Initialize weights and biases
        weights = {
            'h1': tf.Variable(tf.random_normal([input_size, hidden_layer_size])),
            'out': tf.Variable(tf.random_normal([hidden_layer_size, output_size]))
        }
        biases = {
            'b1': tf.Variable(tf.random_normal([hidden_layer_size])),
            'out': tf.Variable(tf.random_normal([output_size]))
        }

        # Define the neural network
        def neural_network(x):
            layer1 = activation_func(tf.add(tf.matmul(x, weights['h1']), biases['b1']))
            output_layer = tf.add(tf.matmul(layer1, weights['out']), biases['out'])
            return output_layer

        logits = neural_network(X)
        predictions = tf.nn.softmax(logits)

        # Define loss and optimizer
        loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits_v2(logits=logits, labels=Y))
        optimizer = tf.train.AdamOptimizer(learning_rate).minimize(loss)

        # Define accuracy metric
        correct_pred = tf.equal(tf.argmax(predictions, 1), tf.argmax(Y, 1))
        accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

        # Start session
        with tf.Session() as sess:
            sess.run(tf.global_variables_initializer())
            train_losses, train_accuracies = [], []
            start_time = time.time()

            for epoch in range(epochs):
                avg_loss = 0
                total_batches = 0
                iterator = tf.compat.v1.data.make_one_shot_iterator(train_data)
                next_batch = iterator.get_next()

                while True:
                    try:
                        batch_x, batch_y = sess.run(next_batch)
                        _, c, acc = sess.run([optimizer, loss, accuracy], feed_dict={X: batch_x, Y: batch_y})
                        avg_loss += c
                        total_batches += 1
                    except tf.errors.OutOfRangeError:
                        break

                avg_loss /= total_batches
                train_losses.append(avg_loss)
                train_accuracies.append(acc)
                print(f"Epoch {epoch+1}, Loss: {avg_loss:.4f}, Accuracy: {acc:.4f}")

            end_time = time.time()
            execution_time = end_time - start_time

            # Evaluate model
            test_acc = []
            y_true, y_pred = [], []
            iterator = tf.compat.v1.data.make_one_shot_iterator(test_data)
            next_batch = iterator.get_next()

            while True:
                try:
                    batch_x, batch_y = sess.run(next_batch)
                    acc, preds = sess.run([accuracy, predictions], feed_dict={X: batch_x, Y: batch_y})
                    test_acc.append(acc)
                    y_true.extend(np.argmax(batch_y, axis=1))
                    y_pred.extend(np.argmax(preds, axis=1))
                except tf.errors.OutOfRangeError:
                    break

            final_test_accuracy = np.mean(test_acc)
            results.append((activation_name, hidden_layer_size, final_test_accuracy, execution_time))

            print(f"Final Test Accuracy: {final_test_accuracy:.4f}")
            print(f"Execution Time: {execution_time:.2f} seconds\n")

            # Plot loss and accuracy curves
            plt.figure(figsize=(12, 5))
            plt.subplot(1, 2, 1)
            plt.plot(range(epochs), train_losses, label='Loss')
            plt.xlabel('Epochs')
            plt.ylabel('Loss')
            plt.title(f'Loss Curve - {activation_name}, {hidden_layer_size}')
            plt.legend()

            plt.subplot(1, 2, 2)
            plt.plot(range(epochs), train_accuracies, label='Accuracy', color='green')
            plt.xlabel('Epochs')
            plt.ylabel('Accuracy')
            plt.title(f'Accuracy Curve - {activation_name}, {hidden_layer_size}')
            plt.legend()
            plt.show()

            # Confusion matrix
            cm = confusion_matrix(y_true, y_pred)
            plt.figure(figsize=(8, 6))
            sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=range(10), yticklabels=range(10))
            plt.xlabel('Predicted')
            plt.ylabel('Actual')
            plt.title(f'Confusion Matrix - {activation_name}, {hidden_layer_size}')
            plt.show()

# Print summary of results
print("\nHyperparameter Tuning Results:")
for activation, hl_size, acc, time_taken in results:
    print(f"Activation: {activation}, Hidden Layer: {hl_size}, Test Accuracy: {acc:.4f}, Time: {time_taken:.2f}s")
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.11/dist-packages/tensorflow/python/compat/v2_compat.py:98: disable_resource_variables (from tensorflow.python.ops.resource_variables_toggle) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# WARNING:absl:Variant folder /root/tensorflow_datasets/mnist/3.0.1 has no dataset_info.json
# Downloading and preparing dataset Unknown size (download: Unknown size, generated: Unknown size, total: Unknown size) to /root/tensorflow_datasets/mnist/3.0.1...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# Generating splits...:   0%|          | 0/2 [00:00<?, ? splits/s]
# Generating train examples...: 0 examples [00:00, ? examples/s]
# Shuffling /root/tensorflow_datasets/mnist/incomplete.OFYOXV_3.0.1/mnist-train.tfrecord*...:   0%|          | 0…
# Generating test examples...: 0 examples [00:00, ? examples/s]
# Shuffling /root/tensorflow_datasets/mnist/incomplete.OFYOXV_3.0.1/mnist-test.tfrecord*...:   0%|          | 0/…
# Dataset mnist downloaded and prepared to /root/tensorflow_datasets/mnist/3.0.1. Subsequent calls will reuse this data.
# Training with Activation: relu, Hidden Layer Size: 256
# Epoch 1, Loss: 2.6944, Accuracy: 0.9000
# Epoch 2, Loss: 0.3993, Accuracy: 0.9000
# Epoch 3, Loss: 0.3086, Accuracy: 1.0000
# Epoch 4, Loss: 0.2669, Accuracy: 0.9000
# Epoch 5, Loss: 0.2524, Accuracy: 1.0000
# Epoch 6, Loss: 0.2315, Accuracy: 1.0000
# Epoch 7, Loss: 0.2259, Accuracy: 1.0000
# Epoch 8, Loss: 0.2175, Accuracy: 1.0000
# Epoch 9, Loss: 0.2123, Accuracy: 1.0000
# Epoch 10, Loss: 0.1993, Accuracy: 1.0000
# Epoch 11, Loss: 0.1901, Accuracy: 1.0000
# Epoch 12, Loss: 0.1973, Accuracy: 1.0000
# Epoch 13, Loss: 0.1867, Accuracy: 1.0000
# Epoch 14, Loss: 0.1827, Accuracy: 1.0000
# Epoch 15, Loss: 0.3940, Accuracy: 1.0000
# Epoch 16, Loss: 0.3598, Accuracy: 1.0000
# Epoch 17, Loss: 0.3742, Accuracy: 1.0000
# Epoch 18, Loss: 0.3681, Accuracy: 1.0000
# Epoch 19, Loss: 0.3716, Accuracy: 1.0000
# Epoch 20, Loss: 0.3652, Accuracy: 1.0000
# Epoch 21, Loss: 0.3719, Accuracy: 1.0000
# Epoch 22, Loss: 0.3479, Accuracy: 0.9000
# Epoch 23, Loss: 0.3350, Accuracy: 1.0000
# Epoch 24, Loss: 0.3339, Accuracy: 1.0000
# Epoch 25, Loss: 0.3264, Accuracy: 1.0000
# Epoch 26, Loss: 0.3312, Accuracy: 1.0000
# Epoch 27, Loss: 0.3401, Accuracy: 1.0000
# Epoch 28, Loss: 0.3499, Accuracy: 1.0000
# Epoch 29, Loss: 0.3369, Accuracy: 1.0000
# Epoch 30, Loss: 0.3440, Accuracy: 1.0000
# Epoch 31, Loss: 0.3208, Accuracy: 1.0000
# Epoch 32, Loss: 0.3142, Accuracy: 0.8000
# Epoch 33, Loss: 0.3280, Accuracy: 0.9000
# Epoch 34, Loss: 0.2980, Accuracy: 1.0000
# Epoch 35, Loss: 0.2987, Accuracy: 1.0000
# Epoch 36, Loss: 0.2962, Accuracy: 1.0000
# Epoch 37, Loss: 0.3235, Accuracy: 0.9000
# Epoch 38, Loss: 0.3250, Accuracy: 1.0000
# Epoch 39, Loss: 0.3084, Accuracy: 1.0000
# Epoch 40, Loss: 0.3111, Accuracy: 1.0000
# Epoch 41, Loss: 0.3123, Accuracy: 1.0000
# Epoch 42, Loss: 0.2999, Accuracy: 1.0000
# Epoch 43, Loss: 0.3007, Accuracy: 1.0000
# Epoch 44, Loss: 0.2829, Accuracy: 1.0000
# Epoch 45, Loss: 0.3071, Accuracy: 1.0000
# Epoch 46, Loss: 0.3058, Accuracy: 1.0000
# Epoch 47, Loss: 0.2964, Accuracy: 1.0000
# Epoch 48, Loss: 0.3005, Accuracy: 1.0000
# Epoch 49, Loss: 0.2984, Accuracy: 0.9000
# Epoch 50, Loss: 0.2948, Accuracy: 1.0000
# Final Test Accuracy: 0.9619
# Execution Time: 700.17 seconds
# Training with Activation: tanh, Hidden Layer Size: 128
# Epoch 1, Loss: 0.7396, Accuracy: 0.8000
# Epoch 2, Loss: 0.3916, Accuracy: 0.9000
# Epoch 3, Loss: 0.3431, Accuracy: 1.0000
# Epoch 4, Loss: 0.3160, Accuracy: 1.0000
# Epoch 5, Loss: 0.2897, Accuracy: 1.0000
# Epoch 6, Loss: 0.2826, Accuracy: 1.0000
# Epoch 7, Loss: 0.2610, Accuracy: 0.9000
# Epoch 8, Loss: 0.2791, Accuracy: 1.0000
# Epoch 9, Loss: 0.2639, Accuracy: 1.0000
# Epoch 10, Loss: 0.2556, Accuracy: 1.0000
# Epoch 11, Loss: 0.2534, Accuracy: 1.0000
# Epoch 12, Loss: 0.2463, Accuracy: 1.0000
# Epoch 13, Loss: 0.2325, Accuracy: 1.0000
# Epoch 14, Loss: 0.2259, Accuracy: 1.0000
# Epoch 15, Loss: 0.2304, Accuracy: 1.0000
# Epoch 16, Loss: 0.2227, Accuracy: 1.0000
# Epoch 17, Loss: 0.2258, Accuracy: 1.0000
# Epoch 18, Loss: 0.2219, Accuracy: 0.9000
# Epoch 19, Loss: 0.2149, Accuracy: 1.0000
# Epoch 20, Loss: 0.2156, Accuracy: 0.9000
# Epoch 21, Loss: 0.2116, Accuracy: 0.9000
# Epoch 22, Loss: 0.2088, Accuracy: 1.0000
# Epoch 23, Loss: 0.2124, Accuracy: 1.0000
# Epoch 24, Loss: 0.1999, Accuracy: 1.0000
# Epoch 25, Loss: 0.2103, Accuracy: 1.0000
# Epoch 26, Loss: 0.1974, Accuracy: 1.0000
# Epoch 27, Loss: 0.1919, Accuracy: 1.0000
# Epoch 28, Loss: 0.1968, Accuracy: 1.0000
# Epoch 29, Loss: 0.1860, Accuracy: 1.0000
# Epoch 30, Loss: 0.1916, Accuracy: 1.0000
# Epoch 31, Loss: 0.1933, Accuracy: 1.0000
# Epoch 32, Loss: 0.1947, Accuracy: 1.0000
# Epoch 33, Loss: 0.1888, Accuracy: 1.0000
# Epoch 34, Loss: 0.1915, Accuracy: 1.0000
# Epoch 35, Loss: 0.1927, Accuracy: 1.0000
# Epoch 36, Loss: 0.1884, Accuracy: 0.9000
# Epoch 37, Loss: 0.1834, Accuracy: 1.0000
# Epoch 38, Loss: 0.1765, Accuracy: 1.0000
# Epoch 39, Loss: 0.1862, Accuracy: 1.0000
# Epoch 40, Loss: 0.1759, Accuracy: 1.0000
# Epoch 41, Loss: 0.1818, Accuracy: 1.0000
# Epoch 42, Loss: 0.1857, Accuracy: 1.0000
# Epoch 43, Loss: 0.1735, Accuracy: 0.9000
# Epoch 44, Loss: 0.1839, Accuracy: 1.0000
# Epoch 45, Loss: 0.1753, Accuracy: 1.0000
# Epoch 46, Loss: 0.1713, Accuracy: 1.0000
# Epoch 47, Loss: 0.1634, Accuracy: 1.0000
# Epoch 48, Loss: 0.1674, Accuracy: 1.0000
# Epoch 49, Loss: 0.1846, Accuracy: 1.0000
# Epoch 50, Loss: 0.1640, Accuracy: 1.0000
# Final Test Accuracy: 0.9565
# Execution Time: 704.14 seconds
# Training with Activation: tanh, Hidden Layer Size: 64
# Epoch 1, Loss: 0.6095, Accuracy: 1.0000
# Epoch 2, Loss: 0.3131, Accuracy: 0.9000
# Epoch 3, Loss: 0.2835, Accuracy: 1.0000
# Epoch 4, Loss: 0.2619, Accuracy: 0.9000
# Epoch 5, Loss: 0.2455, Accuracy: 0.9000
# Epoch 6, Loss: 0.2314, Accuracy: 1.0000
# Epoch 7, Loss: 0.2197, Accuracy: 0.9000
# Epoch 8, Loss: 0.2180, Accuracy: 0.8000
# Epoch 9, Loss: 0.2055, Accuracy: 1.0000
# Epoch 10, Loss: 0.2022, Accuracy: 0.9000
# Epoch 11, Loss: 0.1899, Accuracy: 0.9000
# Epoch 12, Loss: 0.1880, Accuracy: 0.9000
# Epoch 13, Loss: 0.1828, Accuracy: 0.9000
# Epoch 14, Loss: 0.1783, Accuracy: 1.0000
# Epoch 15, Loss: 0.1777, Accuracy: 0.9000
# Epoch 16, Loss: 0.1716, Accuracy: 0.9000
# Epoch 17, Loss: 0.1662, Accuracy: 0.9000
# Epoch 18, Loss: 0.1712, Accuracy: 1.0000
# Epoch 19, Loss: 0.1704, Accuracy: 1.0000
# Epoch 20, Loss: 0.1618, Accuracy: 0.8000
# Epoch 21, Loss: 0.1615, Accuracy: 1.0000
# Epoch 22, Loss: 0.1589, Accuracy: 1.0000
# Epoch 23, Loss: 0.1526, Accuracy: 0.9000
# Epoch 24, Loss: 0.1568, Accuracy: 1.0000
# Epoch 25, Loss: 0.1530, Accuracy: 1.0000
# Epoch 26, Loss: 0.1514, Accuracy: 0.9000
# Epoch 27, Loss: 0.1513, Accuracy: 0.9000
# Epoch 28, Loss: 0.1504, Accuracy: 0.9000
# Epoch 29, Loss: 0.1521, Accuracy: 1.0000
# Epoch 30, Loss: 0.1464, Accuracy: 1.0000
# Epoch 31, Loss: 0.1485, Accuracy: 1.0000
# Epoch 32, Loss: 0.1465, Accuracy: 1.0000
# Epoch 33, Loss: 0.1440, Accuracy: 0.9000
# Epoch 34, Loss: 0.1408, Accuracy: 1.0000
# Epoch 35, Loss: 0.1425, Accuracy: 1.0000
# Epoch 36, Loss: 0.1408, Accuracy: 0.9000
# Epoch 37, Loss: 0.1378, Accuracy: 1.0000
# Epoch 38, Loss: 0.1360, Accuracy: 1.0000
# Epoch 39, Loss: 0.1375, Accuracy: 1.0000
# Epoch 40, Loss: 0.1378, Accuracy: 1.0000
# Epoch 41, Loss: 0.1330, Accuracy: 0.9000
# Epoch 42, Loss: 0.1254, Accuracy: 0.9000
# Epoch 43, Loss: 0.1335, Accuracy: 1.0000
# Epoch 44, Loss: 0.1235, Accuracy: 1.0000
# Epoch 45, Loss: 0.1283, Accuracy: 0.9000
# Epoch 46, Loss: 0.1258, Accuracy: 1.0000
# Epoch 47, Loss: 0.1289, Accuracy: 1.0000
# Epoch 48, Loss: 0.1225, Accuracy: 1.0000
# Epoch 49, Loss: 0.1233, Accuracy: 0.8000
# Epoch 50, Loss: 0.1270, Accuracy: 1.0000
# Final Test Accuracy: 0.9563
# Execution Time: 704.40 seconds
# Hyperparameter Tuning Results:
# Activation: relu, Hidden Layer: 256, Test Accuracy: 0.9658, Time: 705.35s
# Activation: relu, Hidden Layer: 128, Test Accuracy: 0.9530, Time: 696.29s
# Activation: relu, Hidden Layer: 64, Test Accuracy: 0.9461, Time: 712.43s
# Activation: sigmoid, Hidden Layer: 256, Test Accuracy: 0.9671, Time: 743.24s
# Activation: sigmoid, Hidden Layer: 128, Test Accuracy: 0.9712, Time: 708.54s
# Activation: sigmoid, Hidden Layer: 64, Test Accuracy: 0.9672, Time: 702.58s
# Activation: tanh, Hidden Layer: 256, Test Accuracy: 0.9619, Time: 700.17s
# Activation: tanh, Hidden Layer: 128, Test Accuracy: 0.9565, Time: 704.14s
# Activation: tanh, Hidden Layer: 64, Test Accuracy: 0.9563, Time: 704.40s
